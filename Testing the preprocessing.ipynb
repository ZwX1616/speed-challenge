# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import csv
from processing import process
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
if '__file__' not in globals():
    CURRENT_DIR = os.getcwd()
else:
    CURRENT_DIR = os.path.dirname(os.path.realpath(__file__))
DATA_PATH =  os.path.join(CURRENT_DIR, 'data')
SHORT_TRAIN_VIDEO = os.path.join(DATA_PATH, 'short-train.mp4')
PREPARED_DATA_PATH = os.path.join(DATA_PATH, 'prepared-data')
PREPARED_IMGS_SHORT_TRAIN = os.path.join(PREPARED_DATA_PATH, 'short-train_imgs')
FLOW_IMGS_SHORT_TRAIN = os.path.join(PREPARED_DATA_PATH, 'flow_short-train_imgs')
SIZE = (150, 150)

# %%
train_meta = pd.read_csv(os.path.join(PREPARED_DATA_PATH, 'short-train_meta.csv'))

# %%
train_meta.head()
# Out:
#                                           frame_path  frame_index      speed
# 0  /Users/justinglibert/Dev/repositories/personal...            0  28.105569
# 1  /Users/justinglibert/Dev/repositories/personal...            1  28.105569
# 2  /Users/justinglibert/Dev/repositories/personal...            2  28.106527
# 3  /Users/justinglibert/Dev/repositories/personal...            3  28.130404
# 4  /Users/justinglibert/Dev/repositories/personal...            4  28.109243

# %%
#let's try the cropping + optical flow on one pair of frame

# %%
frame1 = train_meta.iloc[[0]]
frame2 = train_meta.iloc[[1]]

# %%
frame1_path = frame1['frame_path'].values[0]
frame2_path = frame2['frame_path'].values[0]
print(frame1_path)
print(frame2_path)
# Out:
# /Users/justinglibert/Dev/repositories/personal/speed-challenge/data/prepared-data/short-train_imgs/0.jpg
# /Users/justinglibert/Dev/repositories/personal/speed-challenge/data/prepared-data/short-train_imgs/1.jpg

# %%
flow, frame1_cropped, frame2_cropped = process(frame1_path, frame2_path, SIZE, debug=True)

# %%
plt.imshow(flow)
plt.show()

plt.imshow(frame1_cropped)
plt.show()

plt.imshow(frame2_cropped)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
